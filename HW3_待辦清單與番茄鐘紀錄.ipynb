# %% [markdown]
# <a href="https://colab.research.google.com/github/leo5358/PL_1142/blob/main/HW3_%E5%BE%85%E8%BE%A6%E6%B8%85%E5%96%AE%E8%88%87%E7%95%AA%E8%8C%84%E9%90%98%E7%B4%80%E9%8C%84.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip -q install gspread gspread_dataframe google-auth google-auth-oauthlib google-auth-httplib2 \
               gradio pandas beautifulsoup4 google-generativeai python-dateutil icalendar

# %%
import os, time, uuid, re, json, datetime
from datetime import datetime as dt, timedelta
from dateutil.tz import gettz
import pandas as pd
import gradio as gr
import requests
from bs4 import BeautifulSoup

import google.generativeai as genai

# Google Auth & Sheets
from google.colab import auth
import gspread
from gspread_dataframe import set_with_dataframe, get_as_dataframe
from google.auth.transport.requests import Request
from google.oauth2 import service_account
from google.auth import default
# Out:
# /usr/local/lib/python3.12/dist-packages/google/colab/_import_hooks/_hook_injector.py:55: FutureWarning:
#
# All support for the `google.generativeai` package has ended. It will no longer be receiving
# updates or bug fixes. Please switch to the `google.genai` package as soon as possible.
# See README for more details:
#
# https://github.com/google-gemini/deprecated-generative-ai-python/blob/main/README.md
#
#   loader.exec_module(module)

# %%
from google.colab import auth
auth.authenticate_user()

import gspread
from google.auth import default
creds, _ = default()

gc = gspread.authorize(creds)

# %%
from google.colab import userdata

# 從 Colab Secrets 中獲取 API 金鑰
api_key = userdata.get('gemini')

# 使用獲取的金鑰配置 genai
genai.configure(api_key=api_key)

model = genai.GenerativeModel('gemini-2.5-pro')

# %%
SHEET_URL = "https://docs.google.com/spreadsheets/d/1ge-RkD_jfq4NNu5egU2Fk48pBttx6vpIvsPWIh96B_o/edit?usp=sharing"
WORKSHEET_NAME = "工作表3"
TIMEZONE = "Asia/Taipei"

# %%
import pandas as pd
# read data and put it in a dataframe
# 在 google 工作表載入 gsheets
gsheets = gc.open_by_url(SHEET_URL)


# 從 gsheets 的 All-whiteboard-device 載入 sheets
sh = gsheets.worksheet(WORKSHEET_NAME).get_all_values()
# 將 sheets1 資料載入 pd 的 DataFrame 進行分析
df = pd.DataFrame(sh[1:], columns=sh[0])
# 取得最前面的5筆資料
df.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
def ensure_spreadsheet(url):
    try:
        sh = gc.open_by_url(url)
    except Exception as e:
        print(f"無法開啟指定的 URL，請確認網址正確且具有編輯權限: {e}")
        raise e
    return sh
sh = ensure_spreadsheet(SHEET_URL)

# %%
import requests
from icalendar import Calendar
from datetime import datetime
import uuid


def sync_moodle_calendar(ics_url):
    global tasks_df
    try:
        resp = requests.get(ics_url)
        resp.raise_for_status()

        cal = Calendar.from_ical(resp.text)
        new_tasks = []
        _now = tznow().isoformat()

        for component in cal.walk():
            if component.name == "VEVENT":
                # 取得事件名稱 (作業名稱)
                summary = str(component.get('summary'))
                # 取得截止時間
                dtend = component.get('dtend').dt

                # 確保時間格式是 YYYY-MM-DD
                if isinstance(dtend, datetime):
                    due_date = dtend.strftime("%Y-%m-%d")
                else:
                    due_date = dtend.strftime("%Y-%m-%d") # 處理 date object

                new_tasks.append({
                    "id": str(uuid.uuid4())[:8],
                    "task": f"[Moodle] {summary}",
                    "status": "todo",
                    "priority": "H", # 作業通常優先級高
                    "est_min": 60,   # 預設給個 60 分鐘
                    "start_time": "",
                    "end_time": "",
                    "actual_min": 0,
                    "pomodoros": 0,
                    "due_date": due_date,
                    "labels": "from:moodle_cal",
                    "notes": component.get('description', ''),
                    "created_at": _now,
                    "updated_at": _now,
                    "completed_at": "",
                    "planned_for": ""
                })

        if new_tasks:
            # 這裡可以加一個邏輯：檢查 task 名稱是否已經在 tasks_df 裡，避免重複新增
            tasks_df = pd.concat([tasks_df, pd.DataFrame(new_tasks)], ignore_index=True)
            write_df(ws_tasks, tasks_df, TASKS_HEADER)
            return f"成功從 Moodle 日曆同步了 {len(new_tasks)} 項作業！"
        return "Moodle 日曆中沒有找到未來的事件。"

    except Exception as e:
        return f"同步失敗：{e}"

# %%
# === 前端 JavaScript 計時器與特效邏輯 ===
start_work_js = """
function(task, cycles, custom_min) {
    if (!task) return [task, cycles, custom_min];
    let display = document.getElementById('timer_display');
    if (!display) return [task, cycles, custom_min];

    let timer = (custom_min || 25) * 60;
    let m, s;

    if(window.pomoInterval) clearInterval(window.pomoInterval);
    if(window.blinkInterval) clearInterval(window.blinkInterval);
    display.style.visibility = 'visible';
    display.style.color = "#d9534f";

    window.pomoInterval = setInterval(function () {
        m = parseInt(timer / 60, 10);
        s = parseInt(timer % 60, 10);
        m = m < 10 ? "0" + m : m;
        s = s < 10 ? "0" + s : s;
        display.innerHTML = m + ":" + s;

        if (--timer < 0) {
            clearInterval(window.pomoInterval);
            display.innerHTML = "時間到";

            // 產生提示音
            try {
                let ctx = new (window.AudioContext || window.webkitAudioContext)();
                let osc = ctx.createOscillator();
                osc.type = 'sine';
                osc.frequency.setValueAtTime(880, ctx.currentTime);
                osc.connect(ctx.destination);
                osc.start();
                osc.stop(ctx.currentTime + 0.5);
            } catch(e) { console.log("音效播放失敗", e); }

            // 文字閃爍特效
            window.blinkInterval = setInterval(() => {
                display.style.visibility = (display.style.visibility === 'hidden' ? 'visible' : 'hidden');
            }, 300);

            // 延遲 2.5 秒後自動點擊「結束工作」按鈕進行記錄
            setTimeout(() => {
                let endBtn = document.getElementById('btn_end_work');
                if(endBtn) endBtn.click();
            }, 2500);
        }
    }, 1000);
    return [task, cycles, custom_min];
}
"""

start_break_js = """
function(task, cycles, custom_min) {
    if (!task) return [task, cycles, custom_min];
    let display = document.getElementById('timer_display');
    if (!display) return [task, cycles, custom_min];

    let timer = (custom_min || 5) * 60;
    let m, s;

    if(window.pomoInterval) clearInterval(window.pomoInterval);
    if(window.blinkInterval) clearInterval(window.blinkInterval);
    display.style.visibility = 'visible';
    display.style.color = "#5cb85c";

    window.pomoInterval = setInterval(function () {
        m = parseInt(timer / 60, 10);
        s = parseInt(timer % 60, 10);
        m = m < 10 ? "0" + m : m;
        s = s < 10 ? "0" + s : s;
        display.innerHTML = m + ":" + s;

        if (--timer < 0) {
            clearInterval(window.pomoInterval);
            display.innerHTML = "時間到";

            try {
                let ctx = new (window.AudioContext || window.webkitAudioContext)();
                let osc = ctx.createOscillator();
                osc.type = 'sine';
                osc.frequency.setValueAtTime(880, ctx.currentTime);
                osc.connect(ctx.destination);
                osc.start();
                osc.stop(ctx.currentTime + 0.5);
            } catch(e) { console.log("音效播放失敗", e); }

            window.blinkInterval = setInterval(() => {
                display.style.visibility = (display.style.visibility === 'hidden' ? 'visible' : 'hidden');
            }, 300);

            setTimeout(() => {
                let endBtn = document.getElementById('btn_end_break');
                if(endBtn) endBtn.click();
            }, 2500);
        }
    }, 1000);
    return [task, cycles, custom_min];
}
"""

stop_js = """
function(task, note) {
    if(window.pomoInterval) clearInterval(window.pomoInterval);
    if(window.blinkInterval) clearInterval(window.blinkInterval);
    let display = document.getElementById('timer_display');
    if (display) {
        display.innerHTML = "00:00";
        display.style.color = "#333";
        display.style.visibility = 'visible';
    }
    return [task, note];
}
"""

# %%
def ensure_worksheet(sh, title, header):
    try:
        ws = sh.worksheet(title)
    except gspread.WorksheetNotFound:
        ws = sh.add_worksheet(title=title, rows="1000", cols=str(len(header)+5))
        ws.update([header])
    # 若沒有表頭就補上
    data = ws.get_all_values()
    if not data or (data and data[0] != header):
        ws.clear()
        ws.update([header])
    return ws

TASKS_HEADER = [
    "id","task","status","priority","est_min","start_time","end_time",
    "actual_min","pomodoros","due_date","labels","notes",
    "created_at","updated_at","completed_at","planned_for"
]
LOGS_HEADER = [
    "log_id","task_id","phase","start_ts","end_ts","minutes","cycles","note"
]
CLIPS_HEADER = ["clip_id","url","selector","text","href","created_at","added_to_task"]

ws_tasks = ensure_worksheet(sh, "tasks", TASKS_HEADER)
ws_logs  = ensure_worksheet(sh, "pomodoro_logs", LOGS_HEADER)
ws_clips = ensure_worksheet(sh, "web_clips", CLIPS_HEADER)

def tznow():
    return dt.now(gettz(TIMEZONE))

def read_df(ws, header):
    df = get_as_dataframe(ws, evaluate_formulas=True, header=0)
    if df is None or df.empty:
        return pd.DataFrame(columns=header)
    df = df.fillna("")
    # 保證欄位齊全
    for c in header:
        if c not in df.columns:
            df[c] = ""
    # 型別微調
    if "est_min" in df.columns:
        df["est_min"] = pd.to_numeric(df["est_min"], errors="coerce").fillna(0).astype(int)
    if "actual_min" in df.columns:
        df["actual_min"] = pd.to_numeric(df["actual_min"], errors="coerce").fillna(0).astype(int)
    if "pomodoros" in df.columns:
        df["pomodoros"] = pd.to_numeric(df["pomodoros"], errors="coerce").fillna(0).astype(int)
    return df[header]

def write_df(ws, df, header):
    if df.empty:
        ws.clear()
        ws.update([header])
        return
    # 轉字串避免 gspread 型別問題
    df_out = df.copy()
    for c in df_out.columns:
        df_out[c] = df_out[c].astype(str)
    ws.clear()
    ws.update([header] + df_out.values.tolist())

def refresh_all():
    return (
        read_df(ws_tasks, TASKS_HEADER).copy(),
        read_df(ws_logs, LOGS_HEADER).copy(),
        read_df(ws_clips, CLIPS_HEADER).copy()
    )

tasks_df, logs_df, clips_df = refresh_all()

def add_task(task, priority, est_min, due_date, labels, notes, planned_for):
    global tasks_df
    _now = tznow().isoformat()
    new = pd.DataFrame([{
        "id": str(uuid.uuid4())[:8],
        "task": task.strip(),
        "status": "todo",
        "priority": priority or "M",
        "est_min": int(est_min) if est_min else 25,
        "start_time": "",
        "end_time": "",
        "actual_min": 0,
        "pomodoros": 0,
        "due_date": due_date or "",
        "labels": labels or "",
        "notes": notes or "",
        "created_at": _now,
        "updated_at": _now,
        "completed_at": "",
        "planned_for": planned_for or ""  # 可填 today / tomorrow / 空白
    }])
    tasks_df = pd.concat([tasks_df, new], ignore_index=True)
    write_df(ws_tasks, tasks_df, TASKS_HEADER)
    return "✅ 已新增任務", tasks_df

def update_task_status(task_id, new_status):
    global tasks_df
    idx = tasks_df.index[tasks_df["id"] == task_id]
    if len(idx)==0:
        return "⚠️ 找不到任務", tasks_df
    i = idx[0]
    tasks_df.loc[i, "status"] = new_status
    tasks_df.loc[i, "updated_at"] = tznow().isoformat()
    if new_status == "done" and not tasks_df.loc[i, "completed_at"]:
        tasks_df.loc[i, "completed_at"] = tznow().isoformat()
    write_df(ws_tasks, tasks_df, TASKS_HEADER)
    return "✅ 狀態已更新", tasks_df

def load_task_details(task_id):
    global tasks_df
    if not task_id:
        return "", "M", 25, "", "", "", ""
    idx = tasks_df.index[tasks_df["id"] == task_id]
    if len(idx) == 0:
        return "", "M", 25, "", "", "", ""
    r = tasks_df.loc[idx[0]]
    return (
        r["task"],
        r["priority"],
        int(r["est_min"]) if r["est_min"] else 25,
        r["due_date"],
        r["labels"],
        r["notes"],
        r["planned_for"]
    )

def edit_task_details(task_id, task_name, priority, est_min, due_date, labels, notes, planned_for):
    global tasks_df
    if not task_id:
        return "請先選擇要修改的任務", tasks_df
    idx = tasks_df.index[tasks_df["id"] == task_id]
    if len(idx) == 0:
        return "找不到任務", tasks_df

    i = idx[0]
    tasks_df.loc[i, "task"] = task_name.strip()
    tasks_df.loc[i, "priority"] = priority
    tasks_df.loc[i, "est_min"] = int(est_min)
    tasks_df.loc[i, "due_date"] = due_date
    tasks_df.loc[i, "labels"] = labels
    tasks_df.loc[i, "notes"] = notes
    tasks_df.loc[i, "planned_for"] = planned_for
    tasks_df.loc[i, "updated_at"] = tznow().isoformat()

    write_df(ws_tasks, tasks_df, TASKS_HEADER)
    return "已更新任務內容", tasks_df

def delete_task(task_id):
    global tasks_df
    if not task_id:
        return "請先選擇要刪除的任務", tasks_df

    tasks_df = tasks_df[tasks_df["id"] != task_id].reset_index(drop=True)
    write_df(ws_tasks, tasks_df, TASKS_HEADER)
    return "已刪除任務", tasks_df

def mark_done(task_id):
    return update_task_status(task_id, "done")

def recalc_task_actuals(task_id):
    """根據 logs_df 回寫 actual_min 與 pomodoros"""
    global tasks_df, logs_df
    work_logs = logs_df[(logs_df["task_id"]==task_id) & (logs_df["phase"]=="work")]
    total_min = work_logs["minutes"].astype(float).sum() if not work_logs.empty else 0
    pomos = int(round(total_min / 25.0))
    idx = tasks_df.index[tasks_df["id"]==task_id]
    if len(idx)==0: return
    i = idx[0]
    tasks_df.loc[i,"actual_min"] = int(total_min)
    tasks_df.loc[i,"pomodoros"] = pomos
    tasks_df.loc[i,"updated_at"] = tznow().isoformat()

def list_task_choices():
    global tasks_df
    if tasks_df.empty:
        return []
    # 顯示： [status] (P:priority) task  — id
    def row_label(r):
        return f"[{r['status']}] (P:{r['priority']}) {r['task']} — {r['id']}"
    return [(row_label(r), r["id"]) for _, r in tasks_df.iterrows()]

def list_unfinished_task_choices():
    global tasks_df
    if tasks_df.empty:
        return []
    # 只過濾出狀態不是 'done' 的任務
    unfinished = tasks_df[tasks_df["status"] != "done"]
    def row_label(r):
        return f"[{r['status']}] (P:{r['priority']}) {r['task']} — {r['id']}"
    return [(row_label(r), r["id"]) for _, r in unfinished.iterrows()]

def filter_tasks(search_text, status_val):
    global tasks_df
    if tasks_df.empty:
        return tasks_df

    df_filtered = tasks_df.copy()

    # 1. 狀態篩選
    if status_val == "未完成":
        df_filtered = df_filtered[df_filtered["status"].isin(["todo", "in-progress"])]
    elif status_val == "已完成":
        df_filtered = df_filtered[df_filtered["status"] == "done"]

    # 2. 關鍵字篩選 (搜尋任務名稱、備註與標籤)
    if search_text:
        text = search_text.lower()
        mask = (
            df_filtered["task"].str.lower().str.contains(text, na=False) |
            df_filtered["notes"].str.lower().str.contains(text, na=False) |
            df_filtered["labels"].str.lower().str.contains(text, na=False)
        )
        df_filtered = df_filtered[mask]

    return df_filtered

def clear_filter():
    # 回傳：清空搜尋框、重置狀態為未完成、重置表格資料
    return "", "未完成", filter_tasks("", "未完成")

# 我們採「按鈕開始 / 結束」模式（避免後端阻塞），每次按「開始」會先記住 start_ts，
# 按「結束」時計算分鐘並寫入 logs，再回填任務 actual_min / pomodoros。

_active_sessions = {}  # { task_id: {"phase": "work"/"break", "start_ts": iso, "cycles": int} }

def start_phase(task_id, phase, cycles):
    if not task_id: return "⚠️ 請先選擇任務"
    _active_sessions[task_id] = {
        "phase": phase,
        "start_ts": tznow().isoformat(),
        "cycles": int(cycles) if cycles else 1
    }
    return f"▶️ 已開始：{phase}（task: {task_id}）"

def end_phase(task_id, note):
    global logs_df, tasks_df
    if task_id not in _active_sessions:
        return "⚠️ 尚未開始任何階段"
    sess = _active_sessions.pop(task_id)
    start = pd.to_datetime(sess["start_ts"])
    end = tznow()
    minutes = round((end - start).total_seconds() / 60.0, 2)
    log = pd.DataFrame([{
        "log_id": str(uuid.uuid4())[:8],
        "task_id": task_id,
        "phase": sess["phase"],
        "start_ts": start.isoformat(),
        "end_ts": end.isoformat(),
        "minutes": minutes,
        "cycles": int(sess["cycles"]),
        "note": note or ""
    }])
    logs_df = pd.concat([logs_df, log], ignore_index=True)
    write_df(ws_logs, logs_df, LOGS_HEADER)

    # 回填任務
    if sess["phase"] == "work":
        recalc_task_actuals(task_id)
        write_df(ws_tasks, tasks_df, TASKS_HEADER)

    return f"⏹️ 已結束：{sess['phase']}，紀錄 {minutes} 分鐘"

# AI 計畫（Gemini；無金鑰則規則式）
def generate_today_plan():
    global tasks_df

    try:
        cand = tasks_df[tasks_df["status"] != "done"].copy()

        if cand.empty:
            return "目前沒有未完成的任務可供規劃。請先新增任務。"

        pr_order = {"H":0, "M":1, "L":2}
        cand["p_ord"] = cand["priority"].map(pr_order).fillna(3)
        cand = cand.sort_values(["p_ord","est_min"], ascending=[True, True])

        # 檢查環境變數
        try:
            has_api_key = bool(api_key)
        except NameError:
            has_api_key = False

        if has_api_key:
            genai.configure(api_key=api_key)
            sys_prompt = (
                "你是一位任務規劃助理。請把輸入的任務（含估時與優先級）排成三段：morning、afternoon、evening，"
                "並給出每段的重點、順序、每項的時間預估與備註。總時數請大致符合任務估時總和。"
                "回傳以 Markdown 條列，格式：\n"
                "### Morning\n- [任務ID] 任務名稱（預估 xx 分）— 備註\n..."
                "### Afternoon\n...\n### Evening\n...\n"
            )
            items = []
            for _, r in cand.iterrows():
                items.append({
                    "id": r["id"], "task": r["task"], "est_min": int(r["est_min"]),
                    "priority": r["priority"]
                })

            today = tznow().date().isoformat()

            user_content = json.dumps({"today": today, "tasks": items}, ensure_ascii=False)

            try:
                # 檢查 model 是否已定義
                if 'model' not in globals():
                    raise NameError("全域變數 'model' 未定義")

                resp = model.generate_content(sys_prompt + "\n\n" + user_content)
                plan_md = resp.text
            except Exception as e:
                plan_md = f"Gemini 失敗：{e}\n\n改用規則式規劃。"
        else:
            plan_md = "未設定 GEMINI_API_KEY，使用規則式規劃。\n\n"

        # 規則式規劃
        buckets = {"morning": [], "afternoon": [], "evening": []}
        for i, (_, r) in enumerate(cand.iterrows()):
            if i % 3 == 0:
                buckets["morning"].append(r)
            elif i % 3 == 1:
                buckets["afternoon"].append(r)
            else:
                buckets["evening"].append(r)

        def sec_md(name, rows):
            if not rows: return f"### {name.title()}\n（無）\n"
            lines = [f"### {name.title()}"]
            for r in rows:
                lines.append(f"- [{r['id']}] {r['task']}（預估 {int(r['est_min'])} 分，P:{r['priority']}）")
            return "\n".join(lines) + "\n"

        rule_md = sec_md("morning", buckets["morning"]) + "\n" + \
                  sec_md("afternoon", buckets["afternoon"]) + "\n" + \
                  sec_md("evening", buckets["evening"])

        return (plan_md + "\n---\n" + rule_md).strip()

    except Exception as e:
        import traceback
        error_trace = traceback.format_exc()
        return f"執行發生錯誤，請檢查 Colab 的文字輸出區塊。\n\n錯誤細節：\n```\n{error_trace}\n```"

# 今日完成率
def today_summary():
    global tasks_df
    today = tznow().date().isoformat()
    planned = tasks_df[
        ((tasks_df["due_date"]==today) | (tasks_df["planned_for"].str.lower()=="today"))
    ]
    done = planned[planned["status"]=="done"]
    total = len(planned)
    done_n = len(done)
    rate = (done_n/total*100) if total>0 else 0
    return f"📅 今日計畫任務：{total}；✅ 完成：{done_n}；📈 完成率：{rate:.1f}%"

# =========================
# 爬蟲：擷取文字或連結並可加入任務
# =========================
def crawl(url, selector, mode, limit):
    try:
        headers = {
            "User-Agent": "Mozilla/5.0",
            "Cookie": f"MoodleSession={userdata.get('MOODLE_KEY')}"
        }
        resp = requests.get(url, timeout=15, headers=headers)
        resp.raise_for_status()
    except Exception as e:
        return pd.DataFrame(columns=CLIPS_HEADER), f"請求失敗：{e}"

    soup = BeautifulSoup(resp.text, "html.parser")
    nodes = soup.select(selector)
    rows = []
    for i, n in enumerate(nodes[:int(limit) if limit else 20]):
        text = n.get_text(strip=True) if mode in ("text","both") else ""
        href = n.get("href") if mode in ("href","both") else ""
        # 相對連結處理
        if href and href.startswith("/"):
            from urllib.parse import urljoin
            href = urljoin(url, href)
        rows.append({
            "clip_id": str(uuid.uuid4())[:8],
            "url": url,
            "selector": selector,
            "text": text,
            "href": href,
            "created_at": tznow().isoformat(),
            "added_to_task": ""
        })
    df = pd.DataFrame(rows, columns=CLIPS_HEADER)
    return df, f"✅ 擷取 {len(df)} 筆"

def add_clips_as_tasks(clip_ids, default_priority, est_min):
    global clips_df, tasks_df
    if not clip_ids:
        return "⚠️ 請先勾選要加入的爬蟲項目", clips_df, tasks_df
    sel = clips_df[clips_df["clip_id"].isin(clip_ids)]
    _now = tznow().isoformat()
    new_tasks = []
    for _, r in sel.iterrows():
        title = r["text"] or r["href"] or "（未命名）"
        note = f"來源：{r['url']}\n選擇器：{r['selector']}\n連結：{r['href']}"
        new_tasks.append({
            "id": str(uuid.uuid4())[:8],
            "task": title[:120],
            "status": "todo",
            "priority": default_priority or "M",
            "est_min": int(est_min) if est_min else 25,
            "start_time": "",
            "end_time": "",
            "actual_min": 0,
            "pomodoros": 0,
            "due_date": "",
            "labels": "from:crawler",
            "notes": note,
            "created_at": _now,
            "updated_at": _now,
            "completed_at": "",
            "planned_for": ""
        })
    if new_tasks:
        tasks_df = pd.concat([tasks_df, pd.DataFrame(new_tasks)], ignore_index=True)
        # 標記已加入
        clips_df.loc[clips_df["clip_id"].isin(clip_ids), "added_to_task"] = "yes"
        write_df(ws_tasks, tasks_df, TASKS_HEADER)
        write_df(ws_clips, clips_df, CLIPS_HEADER)
        return f"✅ 已加入 {len(new_tasks)} 項為任務", clips_df, tasks_df
    return "⚠️ 無可加入項目", clips_df, tasks_df

# =========================
# Gradio 介面
# =========================
def _refresh():
    global tasks_df, logs_df, clips_df
    tasks_df, logs_df, clips_df = refresh_all()
    return tasks_df, logs_df, clips_df, list_task_choices(), today_summary()

with gr.Blocks(title="待辦清單＋番茄鐘＋AI 計畫（Sheet/Gradio/爬蟲）") as demo:
    gr.Markdown("# 待辦清單與番茄鐘（Google Sheet＋Gradio＋Crawler＋AI 計畫）")
    with gr.Row():
        btn_refresh = gr.Button("重新整理（Sheet → App）")
        out_summary = gr.Markdown(today_summary())

    with gr.Tab("Tasks"):
        # 上半部：側邊欄表單 + 任務表格
        with gr.Row():
            # 左側側邊欄：輸入與修改 (scale=2)
            with gr.Column(scale=2):
                with gr.Group():
                    gr.Markdown("### 任務編輯表單")
                    task = gr.Textbox(label="任務名稱", placeholder="任務描述...")
                    with gr.Row():
                        priority = gr.Dropdown(["H","M","L"], value="M", label="優先級")
                        est_min = gr.Number(value=25, label="預估(分)", precision=0)
                    due_date = gr.Textbox(label="到期日 (YYYY-MM-DD)")
                    planned_for = gr.Dropdown(["","today","tomorrow"], value="", label="規劃歸屬")
                    labels = gr.Textbox(label="標籤")
                    notes = gr.Textbox(label="備註", lines=3)

                    with gr.Row():
                        btn_add = gr.Button("新增任務", variant="primary")
                        btn_edit_save = gr.Button("儲存修改", variant="secondary")
                    msg_add = gr.Markdown()

            # 右側主區域：任務清單表格 (scale=3)
            with gr.Column(scale=3):
                with gr.Group():
                    gr.Markdown("### 任務清單瀏覽與篩選")

                    # 新增的篩選與搜尋操作區
                    with gr.Row():
                        search_box = gr.Textbox(label="關鍵字搜尋", placeholder="輸入名稱、標籤或備註...", scale=2)
                        status_filter = gr.Radio(["全部", "未完成", "已完成"], value="未完成", label="狀態篩選", scale=2)
                        btn_clear_filter = gr.Button("清除篩選", scale=1)

                    # 將表格的預設值改為經過篩選的結果（預設顯示未完成）
                    grid_tasks = gr.Dataframe(
                        value=filter_tasks("", "未完成"),
                        label="Sheet 資料",
                        interactive=False
                    )
        # 下半部：快速操作區 (針對選中的任務)
        with gr.Group():
            gr.Markdown("### 快速操作與選取")
            with gr.Row():
                with gr.Column(scale=2):
                    task_choice = gr.Dropdown(choices=list_task_choices(), label="1. 選取任務")
                with gr.Column(scale=1):
                    btn_load = gr.Button("📂 載入到左側表單", variant="secondary")

            with gr.Row():
                with gr.Column(scale=2):
                    with gr.Row():
                        new_status = gr.Dropdown(["todo","in-progress","done"], value="in-progress", label="2. 修改狀態")
                        btn_update = gr.Button("更新狀態", variant="secondary")
                        btn_done = gr.Button("快速完成", variant="primary")
                with gr.Column(scale=1):
                    btn_delete = gr.Button("刪除選中任務", variant="stop")

            msg_update = gr.Markdown()

    with gr.Tab("Pomodoro"):
        with gr.Row():
            sel_task = gr.Dropdown(choices=list_unfinished_task_choices(), label="選擇任務")
            cycles = gr.Number(value=1, precision=0, label="番茄數（僅作紀錄）")
            work_min = gr.Number(value=25, precision=0, label="工作時間（分鐘）")
            break_min = gr.Number(value=5, precision=0, label="休息時間（分鐘）")

        timer_display = gr.HTML("<h1 style='text-align: center; font-size: 5em; font-family: monospace; color: #333;' id='timer_display'>00:00</h1>")

        with gr.Row():
            btn_start_work = gr.Button("開始工作")
            note_work = gr.Textbox(label="工作備註（可空白）")
            btn_end_work = gr.Button("結束工作並記錄", elem_id="btn_end_work")
        with gr.Row():
            btn_start_break = gr.Button("開始休息")
            note_break = gr.Textbox(label="休息備註（可空白）")
            btn_end_break = gr.Button("結束休息並記錄", elem_id="btn_end_break")

        msg_pomo = gr.Markdown()
        grid_logs = gr.Dataframe(value=logs_df, label="番茄鐘紀錄", interactive=False)

    with gr.Tab("AI Plan"):
        gr.Markdown("把**今天的任務**排成 **morning / afternoon / evening** 三段行動計畫。若未設 GEMINI_API_KEY，會用規則式。")
        btn_plan = gr.Button(" 產生今日計畫")
        out_plan = gr.Markdown()

    with gr.Tab("Moodle 同步"):
        gr.Markdown("### Moodle 作業同步")
        gr.Markdown("請將從 NTNU Moodle 行事曆取得的 ICS 網址貼在下方。")
        with gr.Row():
            moodle_ics_url = gr.Textbox(label="Moodle 行事曆 ICS 網址", placeholder="https://moodle.ntnu.edu.tw/calendar/export_execute.php?...&preset_what=all&preset_time=recentupcoming")
            btn_sync_moodle = gr.Button("抓取並同步作業")
        msg_moodle = gr.Markdown()

    with gr.Tab("Crawler"):
        url = gr.Textbox(label="目標 URL", placeholder="https://example.com")
        selector = gr.Textbox(label="CSS Selector", value="a.p-3.p-l-0",placeholder="a.news-item / h2.title / div.card a")
        mode = gr.Radio(["text","href","both"], value="text", label="擷取內容")
        limit = gr.Number(value=20, precision=0, label="最多擷取幾筆")
        btn_crawl = gr.Button("🕷️ 開始擷取")
        msg_crawl = gr.Markdown()
        grid_clips = gr.Dataframe(value=clips_df, label="擷取結果（會同步寫入 Sheet）", interactive=True)
        clip_ids = gr.Textbox(label="要加入任務的 clip_id（多個以逗號分隔）")
        default_priority = gr.Dropdown(["H","M","L"], value="L", label="新增任務優先級")
        clip_est = gr.Number(value=25, precision=0, label="新增任務預估分鐘")
        btn_add_clips = gr.Button("➕ 將勾選的擷取項目加入為任務")
        msg_add_clips = gr.Markdown()

    with gr.Tab("Summary"):
        btn_summary = gr.Button("📊 重新計算今日完成率")
        out_summary2 = gr.Markdown()

    # === 綁定動作 ===
    # 篩選器即時聯動
    search_box.change(
        filter_tasks,
        inputs=[search_box, status_filter],
        outputs=[grid_tasks]
    )

    status_filter.change(
        filter_tasks,
        inputs=[search_box, status_filter],
        outputs=[grid_tasks]
    )

    btn_clear_filter.click(
        clear_filter,
        inputs=[],
        outputs=[search_box, status_filter, grid_tasks]
    )

    # 載入任務資料到輸入欄位
    btn_load.click(
        load_task_details,
        inputs=[task_choice],
        outputs=[task, priority, est_min, due_date, labels, notes, planned_for]
    )

    # 修改任務內容
    btn_edit_save.click(
        edit_task_details,
        inputs=[task_choice, task, priority, est_min, due_date, labels, notes, planned_for],
        outputs=[msg_add, grid_tasks]
    ).then(
        lambda: gr.update(choices=list_task_choices()),
        outputs=task_choice
    )

    # 刪除任務
    btn_delete.click(
        delete_task,
        inputs=[task_choice],
        outputs=[msg_update, grid_tasks]
    ).then(
        lambda: gr.update(choices=list_task_choices()),
        outputs=task_choice
    )


    btn_refresh.click(_refresh, outputs=[grid_tasks, grid_logs, grid_clips, task_choice, out_summary])

    btn_add.click(
        add_task,
        inputs=[task, priority, est_min, due_date, labels, notes, planned_for],
        outputs=[msg_add, grid_tasks]
    )

    btn_update.click(
        update_task_status,
        inputs=[task_choice, new_status],
        outputs=[msg_update, grid_tasks]
    )

    btn_done.click(
        mark_done,
        inputs=[task_choice],
        outputs=[msg_update, grid_tasks]
    )

    btn_start_work.click(
        lambda t, c, w: start_phase(t, "work", c),
        inputs=[sel_task, cycles, work_min],
        outputs=[msg_pomo],
        js=start_work_js
    )
    btn_end_work.click(
        end_phase,
        inputs=[sel_task, note_work],
        outputs=[msg_pomo],
        js=stop_js
    )
    btn_start_break.click(
        lambda t, c, b: start_phase(t, "break", c),
        inputs=[sel_task, cycles, break_min],
        outputs=[msg_pomo],
        js=start_break_js
    )
    btn_end_break.click(
        end_phase,
        inputs=[sel_task, note_break],
        outputs=[msg_pomo],
        js=stop_js
    )

    btn_plan.click(generate_today_plan, outputs=[out_plan])

    btn_sync_moodle.click(
        sync_moodle_calendar,
        inputs=[moodle_ics_url],
        outputs=[msg_moodle, grid_tasks]
    )


    def _crawl_and_save(u, s, m, l):
        df, msg = crawl(u, s, m, l)
        # 寫入 web_clips（覆蓋式追加：合併舊資料）
        global clips_df
        if not df.empty:
            clips_df = pd.concat([clips_df, df], ignore_index=True)
            write_df(ws_clips, clips_df, CLIPS_HEADER)
        return msg, clips_df

    btn_crawl.click(_crawl_and_save, inputs=[url, selector, mode, limit], outputs=[msg_crawl, grid_clips])

    def _add_clips(clip_ids_str, pr, est):
        ids = [c.strip() for c in (clip_ids_str or "").split(",") if c.strip()]
        msg, new_clips, new_tasks = add_clips_as_tasks(ids, pr, est)
        return msg, new_clips, new_tasks

    btn_add_clips.click(
        _add_clips,
        inputs=[clip_ids, default_priority, clip_est],
        outputs=[msg_add_clips, grid_clips, grid_tasks]
    )

    btn_summary.click(today_summary, outputs=[out_summary2])
try:
    demo.close()
except:
    pass

demo.launch(debug=True, share=True, inline=False)
# Out:
# Colab notebook detected. This cell will run indefinitely so that you can see errors and logs. To turn off, set debug=False in launch().
# * Running on public URL: https://d9a9358c8edffb0bf0.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# WARNING:tornado.access:429 POST /v1beta/models/gemini-2.5-pro:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 532.33ms
# Keyboard interruption in main thread... closing server.
# Killing tunnel 127.0.0.1:7860 <> https://d9a9358c8edffb0bf0.gradio.live
